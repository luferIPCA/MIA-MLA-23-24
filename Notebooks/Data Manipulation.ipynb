# %% [markdown]
# # Masters' Artificial Intelligence Engineering
#
# First Notebook for MIA courses
#
# by [*lufer*](mailto:lufer@ipca.pt)
#
# ---

# %% [markdown]
# # Datasets on ML Modelling
#
# Contents:
#
# *   Python essencial
# *   Working with Datasets
# *   Features Manipulation
# *   Essencial Data Analysis
# *   Data Visualization

# %% [markdown]
# ## Environment preparation

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Functions

# %%
#functions definition
def show(p): print (p)

#using defined fucntions
show("Lets start")

# %%
#Importing function
#import time
#print("Sleeping")
#time.sleep(30) # sleep for a while; interrupt me!
#print("Done Sleeping")

# %% [markdown]
# ## Código HTML

# %%
# %%html
# <marquee style='width: 30%; color: red;'><b>O Benfica é o maior!</b></marquee>
# Out:
# <marquee style='width: 30%; color: red;'><b>O Benfica é o maior!</b></marquee>

# %% [markdown]
# ## HTML/SVG

# %%
# %%html
# <svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 450 400" width="200" height="200">
#   <rect x="80" y="60" width="250" height="250" rx="20" style="fill:red; stroke:black; fill-opacity:0.7" />
#   <rect x="180" y="110" width="250" height="250" rx="40" style="fill:blue; stroke:black; fill-opacity:0.5;" />
# </svg>
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 450 400" width="200" height="200">
#   <rect x="80" y="60" width="250" height="250" rx="20" style="fill:red; stroke:black; fill-opacity:0.7" />
#   <rect x="180" y="110" width="250" height="250" rx="40" style="fill:blue; stroke:black; fill-opacity:0.5;" />
# </svg>

# %% [markdown]
# # Working with Datasets

# %% [markdown]
# Prepare the environment

# %%
#install phyton
#check if python is installed
# !python --version # Python 3.9.18
# Out:
# Python 3.10.12

# %%
#from sklearn.feature_selection import SelectKBest

# %%
#mount my google onedrive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Check the dataset contents
#
# ## Read a Dataset from a CSV file

# %%
with open('/content/drive/MyDrive/ColabNotebooks/Datasets/test.csv', 'r') as f:
    print(f.read())
# Out:
# id,battery_power,blue,clock_speed,dual_sim,fc,four_g,int_memory,m_dep,mobile_wt,n_cores,pc,px_height,px_width,ram,sc_h,sc_w,talk_time,three_g,touch_screen,wifi
# 1,1043,1,1.8,1,14,0,5,0.1,193,3,16,226,1412,3476,12,7,2,0,1,0
# 2,841,1,0.5,1,4,1,61,0.8,191,5,12,746,857,3895,6,0,7,1,0,0
# 3,1807,1,2.8,0,1,0,27,0.9,186,3,4,1270,1366,2396,17,10,10,0,1,1
# 4,1546,0,0.5,1,18,1,25,0.5,96,8,20,295,1752,3893,10,0,7,1,1,0
# 5,1434,0,1.4,0,11,1,49,0.5,108,6,18,749,810,1773,15,8,7,1,0,1
# 6,1464,1,2.9,1,5,1,50,0.8,198,8,9,569,939,3506,10,7,3,1,1,1
# 7,1718,0,2.4,0,1,0,47,1,156,2,3,1283,1374,3873,14,2,10,0,0,0
# 8,833,0,2.4,1,0,0,62,0.8,111,1,2,1312,1880,1495,7,2,18,0,1,1
# 9,1111,1,2.9,1,9,1,25,0.6,101,5,19,556,876,3485,11,9,10,1,1,0
# 10,1520,0,0.5,0,1,0,25,0.5,171,3,20,52,1009,651,6,0,5,1,0,1
# 11,1500,0,2.2,0,2,0,55,0.6,80,7,6,503,1336,3866,13,7,20,0,1,0
# 12,1343,0,2.9,0,2,1,34,0.8,171,3,6,235,1671,3911,15,8,8,1,1,1
# 13,900,1,1.4,1,0,0,30,1,87,2,3,829,1893,439,6,2,20,1,0,0
# ...

# %%
dataset = pd.read_csv('/content/drive/MyDrive/ColabNotebooks/Datasets/test.csv')

# %% [markdown]
# After read, the dataset is a Dataframe python type.
# Pandas DataFrame is Excel-like Data.

# %%
type(dataset)
# Out:
# pandas.core.frame.DataFrame

# %%
len(dataset)
# Out:
# 1000

# %%
dataset.shape
# Out:
# (1000, 21)

# %%
dataset.head()
# Out:
#    id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0   1           1043     1          1.8         1  14       0           5
# 1   2            841     1          0.5         1   4       1          61
# 2   3           1807     1          2.8         0   1       0          27
# 3   4           1546     0          0.5         1  18       1          25
# 4   5           1434     0          1.4         0  11       1          49
#
#    m_dep  mobile_wt  ...  pc  px_height  px_width   ram  sc_h  sc_w  \
# 0    0.1        193  ...  16        226      1412  3476    12     7
# 1    0.8        191  ...  12        746       857  3895     6     0
# 2    0.9        186  ...   4       1270      1366  2396    17    10
# 3    0.5         96  ...  20        295      1752  3893    10     0
# 4    0.5        108  ...  18        749       810  1773    15     8
#
#    talk_time  three_g  touch_screen  wifi
# 0          2        0             1     0
# ...

# %%
dataset.tail()
# Out:
#        id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 995   996           1700     1          1.9         0   0       1          54
# 996   997            609     0          1.8         1   0       0          13
# 997   998           1185     0          1.4         0   1       1           8
# 998   999           1533     1          0.5         1   0       0          50
# 999  1000           1270     1          0.5         0   4       1          35
#
#      m_dep  mobile_wt  ...  pc  px_height  px_width   ram  sc_h  sc_w  \
# 995    0.5        170  ...  17        644       913  2121    14     8
# 996    0.9        186  ...   2       1152      1632  1933     8     1
# 997    0.5         80  ...  12        477       825  1223     5     0
# 998    0.4        171  ...  12         38       832  2509    15    11
# 999    0.1        140  ...  19        457       608  2828     9     2
#
#      talk_time  three_g  touch_screen  wifi
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             1000 non-null   int64
#  1   battery_power  1000 non-null   int64
#  2   blue           1000 non-null   int64
#  3   clock_speed    1000 non-null   float64
#  4   dual_sim       1000 non-null   int64
#  5   fc             1000 non-null   int64
#  6   four_g         1000 non-null   int64
#  7   int_memory     1000 non-null   int64
#  8   m_dep          1000 non-null   float64
#  9   mobile_wt      1000 non-null   int64
#  10  n_cores        1000 non-null   int64
#  11  pc             1000 non-null   int64
#  12  px_height      1000 non-null   int64
#  13  px_width       1000 non-null   int64
#  14  ram            1000 non-null   int64
#  15  sc_h           1000 non-null   int64
#  16  sc_w           1000 non-null   int64
#  17  talk_time      1000 non-null   int64
# ...

# %%
pd.set_option("display.precision", 2)

# %% [markdown]
# ## Basic Statistics

# %%
dataset.describe()
# Out:
#             id  battery_power     blue  clock_speed  dual_sim       fc  \
# count  1000.00        1000.00  1000.00      1000.00   1000.00  1000.00
# mean    500.50        1248.51     0.52         1.54      0.52     4.59
# std     288.82         432.46     0.50         0.83      0.50     4.46
# min       1.00         500.00     0.00         0.50      0.00     0.00
# 25%     250.75         895.00     0.00         0.70      0.00     1.00
# 50%     500.50        1246.50     1.00         1.50      1.00     3.00
# 75%     750.25        1629.25     1.00         2.30      1.00     7.00
# max    1000.00        1999.00     1.00         3.00      1.00    19.00
#
#         four_g  int_memory    m_dep  mobile_wt  ...       pc  px_height  \
# count  1000.00     1000.00  1000.00    1000.00  ...  1000.00    1000.00
# mean      0.49       33.65     0.52     139.51  ...    10.05     627.12
# std       0.50       18.13     0.28      34.85  ...     6.10     432.93
# ...

# %%
dataset['battery_power'].max()
# Out:
# 1999

# %%
dataset['battery_power'].mean()
# Out:
# 1248.51

# %%
dataset['battery_power'].min()
# Out:
# 500

# %%
dataset['battery_power'].median()
# Out:
# 1246.5

# %% [markdown]
# ## Considering Objects columns (text)

# %% [markdown]
# To analyse objects columns (text values) use "*dataset.describe(include=object)*"

# %%
#dataset.describe(include=object)

# %% [markdown]
# ## Exploring the Dataset

# %%
dataset['battery_power'].count()
# Out:
# 1000

# %%
dataset['battery_power'].value_counts()
# Out:
# 1074    5
# 1981    5
# 529     4
# 1745    4
# 1715    4
#        ..
# 1248    1
# 1392    1
# 1706    1
# 1297    1
# 1185    1
# Name: battery_power, Length: 721, dtype: int64

# %%
dataset[['battery_power','dual_sim']]
# Out:
#      battery_power  dual_sim
# 0             1043         1
# 1              841         1
# 2             1807         0
# 3             1546         1
# 4             1434         0
# ..             ...       ...
# 995           1700         0
# 996            609         1
# 997           1185         0
# 998           1533         1
# 999           1270         0
#
# [1000 rows x 2 columns]

# %%
dataset[['battery_power','dual_sim']].describe(include="all")
# Out:
#        battery_power  dual_sim
# count        1000.00   1000.00
# mean         1248.51      0.52
# std           432.46      0.50
# min           500.00      0.00
# 25%           895.00      0.00
# 50%          1246.50      1.00
# 75%          1629.25      1.00
# max          1999.00      1.00

# %% [markdown]
# # Filtering

# %%
newdf = dataset.query('battery_power>1000')

# %%
newdf
# Out:
#        id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0       1           1043     1          1.8         1  14       0           5
# 2       3           1807     1          2.8         0   1       0          27
# 3       4           1546     0          0.5         1  18       1          25
# 4       5           1434     0          1.4         0  11       1          49
# 5       6           1464     1          2.9         1   5       1          50
# ..    ...            ...   ...          ...       ...  ..     ...         ...
# 992   993           1895     0          0.5         1   0       1          62
# 995   996           1700     1          1.9         0   0       1          54
# 997   998           1185     0          1.4         0   1       1           8
# 998   999           1533     1          0.5         1   0       0          50
# 999  1000           1270     1          0.5         0   4       1          35
#
# ...

# %%
dataset.groupby('dual_sim').sum()
# Out:
#               id  battery_power  blue  clock_speed    fc  four_g  int_memory  \
# dual_sim
# 0         242134         616243   252        749.4  2090     229       16364
# 1         258366         632267   264        791.5  2503     258       17288
#
#           m_dep  mobile_wt  n_cores    pc  px_height  px_width      ram  sc_h  \
# dual_sim
# 0         246.9      67414     2094  4631     301420    595383  1006957  5780
# 1         270.6      72097     2234  5423     325701    644391  1132041  6215
#
#           sc_w  talk_time  three_g  touch_screen  wifi
# dual_sim
# 0         2572       5342      365           233   237
# 1         2744       5743      391           267   270

# %%
dataset.groupby('dual_sim').count()
# Out:
#            id  battery_power  blue  clock_speed   fc  four_g  int_memory  \
# dual_sim
# 0         483            483   483          483  483     483         483
# 1         517            517   517          517  517     517         517
#
#           m_dep  mobile_wt  n_cores   pc  px_height  px_width  ram  sc_h  \
# dual_sim
# 0           483        483      483  483        483       483  483   483
# 1           517        517      517  517        517       517  517   517
#
#           sc_w  talk_time  three_g  touch_screen  wifi
# dual_sim
# 0          483        483      483           483   483
# 1          517        517      517           517   517

# %%
dataset.groupby("dual_sim", sort=False)["n_cores"].sum()
# Out:
# dual_sim
# 1    2234
# 0    2094
# Name: n_cores, dtype: int64

# %% [markdown]
# # Manipulating Features

# %%
ds2 = dataset.copy()

# %%
ds2.shape
# Out:
# (1000, 21)

# %% [markdown]
# ## Deriving new Feature

# %% [markdown]
# New column "difference" results from existing features "battery_power" and "clock_speed"

# %%
ds2["difference"] = ds2.battery_power - ds2.clock_speed

# %%
ds2.shape
# Out:
# (1000, 22)

# %%
ds2["difference"].max()
# Out:
# 1998.5

# %%
ds2.difference.max()
# Out:
# 1998.5

# %% [markdown]
# ## Change features names

# %%
renamed_ds2 = ds2.rename(columns={"difference": "dif"})

# %%
renamed_ds2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             1000 non-null   int64
#  1   battery_power  1000 non-null   int64
#  2   blue           1000 non-null   int64
#  3   clock_speed    1000 non-null   float64
#  4   dual_sim       1000 non-null   int64
#  5   fc             1000 non-null   int64
#  6   four_g         1000 non-null   int64
#  7   int_memory     1000 non-null   int64
#  8   m_dep          1000 non-null   float64
#  9   mobile_wt      1000 non-null   int64
#  10  n_cores        1000 non-null   int64
#  11  pc             1000 non-null   int64
#  12  px_height      1000 non-null   int64
#  13  px_width       1000 non-null   int64
#  14  ram            1000 non-null   int64
#  15  sc_h           1000 non-null   int64
#  16  sc_w           1000 non-null   int64
#  17  talk_time      1000 non-null   int64
# ...

# %% [markdown]
# ## Deleting Features

# %%
renamed_ds2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             1000 non-null   int64
#  1   battery_power  1000 non-null   int64
#  2   blue           1000 non-null   int64
#  3   clock_speed    1000 non-null   float64
#  4   dual_sim       1000 non-null   int64
#  5   fc             1000 non-null   int64
#  6   four_g         1000 non-null   int64
#  7   int_memory     1000 non-null   int64
#  8   m_dep          1000 non-null   float64
#  9   mobile_wt      1000 non-null   int64
#  10  n_cores        1000 non-null   int64
#  11  pc             1000 non-null   int64
#  12  px_height      1000 non-null   int64
#  13  px_width       1000 non-null   int64
#  14  ram            1000 non-null   int64
#  15  sc_h           1000 non-null   int64
#  16  sc_w           1000 non-null   int64
#  17  talk_time      1000 non-null   int64
# ...

# %%
renamed_ds2.drop(['dif'], inplace=True, axis=1)

# %% [markdown]
# ## Controlling the number of Features

# %%
ds2
# Out:
#        id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0       1           1043     1          1.8         1  14       0           5
# 1       2            841     1          0.5         1   4       1          61
# 2       3           1807     1          2.8         0   1       0          27
# 3       4           1546     0          0.5         1  18       1          25
# 4       5           1434     0          1.4         0  11       1          49
# ..    ...            ...   ...          ...       ...  ..     ...         ...
# 995   996           1700     1          1.9         0   0       1          54
# 996   997            609     0          1.8         1   0       0          13
# 997   998           1185     0          1.4         0   1       1           8
# 998   999           1533     1          0.5         1   0       0          50
# 999  1000           1270     1          0.5         0   4       1          35
#
# ...

# %%
ds2['dual_sim'].unique()
# Out:
# array([1, 0])

# %%
ds2['dual_sim'].nunique()
# Out:
# 2

# %%
ds2['dual_sim'].value_counts()
# Out:
# 1    517
# 0    483
# Name: dual_sim, dtype: int64

# %% [markdown]
# ## Make colunms Categories

# %%
t= pd.Categorical(ds2['dual_sim'] )

# %%
t
# Out:
# [1, 1, 0, 1, 0, ..., 0, 1, 0, 1, 0]
# Length: 1000
# Categories (2, int64): [0, 1]

# %%
ds2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             1000 non-null   int64
#  1   battery_power  1000 non-null   int64
#  2   blue           1000 non-null   int64
#  3   clock_speed    1000 non-null   float64
#  4   dual_sim       1000 non-null   int64
#  5   fc             1000 non-null   int64
#  6   four_g         1000 non-null   int64
#  7   int_memory     1000 non-null   int64
#  8   m_dep          1000 non-null   float64
#  9   mobile_wt      1000 non-null   int64
#  10  n_cores        1000 non-null   int64
#  11  pc             1000 non-null   int64
#  12  px_height      1000 non-null   int64
#  13  px_width       1000 non-null   int64
#  14  ram            1000 non-null   int64
#  15  sc_h           1000 non-null   int64
#  16  sc_w           1000 non-null   int64
#  17  talk_time      1000 non-null   int64
# ...

# %%
ds2['dual_sim'] = pd.Categorical(ds2['dual_sim'] )

# %%
ds2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 22 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             1000 non-null   int64
#  1   battery_power  1000 non-null   int64
#  2   blue           1000 non-null   int64
#  3   clock_speed    1000 non-null   float64
#  4   dual_sim       1000 non-null   category
#  5   fc             1000 non-null   int64
#  6   four_g         1000 non-null   int64
#  7   int_memory     1000 non-null   int64
#  8   m_dep          1000 non-null   float64
#  9   mobile_wt      1000 non-null   int64
#  10  n_cores        1000 non-null   int64
#  11  pc             1000 non-null   int64
#  12  px_height      1000 non-null   int64
#  13  px_width       1000 non-null   int64
#  14  ram            1000 non-null   int64
#  15  sc_h           1000 non-null   int64
#  16  sc_w           1000 non-null   int64
#  17  talk_time      1000 non-null   int64
# ...

# %% [markdown]
# ## Cleaning Data

# %% [markdown]
# Cleaning, Normalizing, initializing are some of the required taks over any Dataset

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             1000 non-null   int64
#  1   battery_power  1000 non-null   int64
#  2   blue           1000 non-null   int64
#  3   clock_speed    1000 non-null   float64
#  4   dual_sim       1000 non-null   int64
#  5   fc             1000 non-null   int64
#  6   four_g         1000 non-null   int64
#  7   int_memory     1000 non-null   int64
#  8   m_dep          1000 non-null   float64
#  9   mobile_wt      1000 non-null   int64
#  10  n_cores        1000 non-null   int64
#  11  pc             1000 non-null   int64
#  12  px_height      1000 non-null   int64
#  13  px_width       1000 non-null   int64
#  14  ram            1000 non-null   int64
#  15  sc_h           1000 non-null   int64
#  16  sc_w           1000 non-null   int64
#  17  talk_time      1000 non-null   int64
# ...

# %% [markdown]
# ### Missing Values

# %% [markdown]
# Avoid *null-values*
#
# The current dataset has no null  values. All features have 1000 regists. There can be *Null / None / Nan Values*.
#
# Let analythe the following example:

# %%
#dfimport pandas as pd

data = {'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Eva'],
        'Age': [25, 31, 22, None, 27],
        'Gender': ['F', 'M', None, 'M', 'F'],
        'Salary': [50000, None, 30000, 40000, 60000]}

df = pd.DataFrame(data)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    5 non-null      object
#  1   Age     4 non-null      float64
#  2   Gender  4 non-null      object
#  3   Salary  4 non-null      float64
# dtypes: float64(2), object(2)
# memory usage: 288.0+ bytes

# %% [markdown]
# It is easy to raalize that *Name* has 5  *non-null* values, but the other columns have only 4.

# %%
dfCopy = df.copy()

# %% [markdown]
# ### See the *null* values

# %%
n1 = dfCopy.isnull().any(axis=1)

# %%
n1
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4    False
# dtype: bool

# %% [markdown]
# ### Get only the *null* values

# %%
nullRows = dfCopy[n1]

# %%
nullRows
# Out:
#       Name   Age Gender   Salary
# 1      Bob  31.0      M      NaN
# 2  Charlie  22.0   None  30000.0
# 3    David   NaN      M  40000.0

# %% [markdown]
# ### Get only the *non-null* values

# %%
n2 = dfCopy.notnull().all(axis=1)

# %%
n2
# Out:
# 0     True
# 1    False
# 2    False
# 3    False
# 4     True
# dtype: bool

# %%
nonNullRows = dfCopy[n2]

# %%
nonNullRows
# Out:
#     Name   Age Gender   Salary
# 0  Alice  25.0      F  50000.0
# 4    Eva  27.0      F  60000.0

# %% [markdown]
# ### Using Query Method

# %% [markdown]
# In this example, the != operator compare the column values with themselves, which returns *True* if the value is *null*.

# %%
nullRows = dfCopy.query('Age != Age or Gender != Gender or Salary != Salary')

# %%
nullRows
# Out:
#       Name   Age Gender   Salary
# 1      Bob  31.0      M      NaN
# 2  Charlie  22.0   None  30000.0
# 3    David   NaN      M  40000.0

# %% [markdown]
# ###  Remove rows with missing values
#
# The easiest way to deal with records containing missing values (incomplete records) is to ignore them!

# %%
dfCopy.shape
# Out:
# (5, 4)

# %%
rowsWithoutMissingData = dfCopy.dropna()

# %%
rowsWithoutMissingData.shape
# Out:
# (2, 4)

# %% [markdown]
# ### Remove *Features* with null-values

# %% [markdown]
# Remove problematic columns if they’re not relevant for your analysis.

# %%
dataWithoutMissingColumns = dfCopy.dropna(axis=1)

# %%
dataWithoutMissingColumns
# Out:
#       Name
# 0    Alice
# 1      Bob
# 2  Charlie
# 3    David
# 4      Eva

# %% [markdown]
# ## Spliting Datasets

# %% [markdown]
# ### Spliting by Rows

# %%
dataset

# %%
# splitting dataframe by row index
df1 = dataset.iloc[:500,:]
df2 = dataset.iloc[500:,:]
print(df1)
print("---------------------------")
print(df2)

# %%
ds_1

# %% [markdown]
# ### Spliting by Colmuns (Features)

# %%
# Split the DataFrame using iloc[] by columns
df1 = dataset.iloc[:,:15]
df2 = dataset.iloc[:,15:]
print(df1)
print("---------------------------")
print(df2)
# Out:
#        id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0       1           1043     1          1.8         1  14       0           5
# 1       2            841     1          0.5         1   4       1          61
# 2       3           1807     1          2.8         0   1       0          27
# 3       4           1546     0          0.5         1  18       1          25
# 4       5           1434     0          1.4         0  11       1          49
# ..    ...            ...   ...          ...       ...  ..     ...         ...
# 995   996           1700     1          1.9         0   0       1          54
# 996   997            609     0          1.8         1   0       0          13
# 997   998           1185     0          1.4         0   1       1           8
# 998   999           1533     1          0.5         1   0       0          50
# 999  1000           1270     1          0.5         0   4       1          35
#
# ...

# %% [markdown]
# ### Splitting  Dataframe by groups

# %% [markdown]
# Group the data by column value *dual_sim*. The newly formed dataframe consists of grouped data with *dual_sim* = 1.

# %%
# splitting dataframe by groups
# grouping by particular dataframe column
grouped = dataset.groupby(dataset.dual_sim)
df_new = grouped.get_group(1)
df_new

# %%
dataset.count()

# %% [markdown]
# ### Splitting Pandas Dataframe by sized chunks

# %% [markdown]
# Randon 60%

# %%
# splitting dataframe in a particular size
df_split = dataset.sample(frac=.6)
df_split.reset_index()
#df_split
len(df)
# Out:
# 52

# %% [markdown]
# ### Split  dataframe in different sets

# %% [markdown]
# Shuffle the whole dataset first

# %%
ds3 = dataset.copy()
ds3.sample(frac=1, random_state=42)

# %%
ds3

# %% [markdown]
# Split in two dataframes

# %%
list_of_dataframes = np.array_split(ds3, 2)
print("First:")
list_of_dataframes[0]
print("Second:")
list_of_dataframes[1]

# %% [markdown]
# ## Generate a new Dataset
# After the dataset analysis it could be necessary to generate a new dataset.

# %%
#import os
#print(os.getcwd())

filePath='/content/drive/MyDrive/ColabNotebooks/Datasets/'
f=dfCopy.to_csv(filePath+'newDataSet.csv', sep=';', index=False)

# %% [markdown]
# ## Exporting only a few features

# %%
dfCopy.to_csv(filePath+'newDataSet2.csv',columns=['Age','Salary'])

# %% [markdown]
# ## Replacing mising values

# %%
dfCopy["Age"].fillna(\
                     value="Unknown",\
                     inplace=True)

# %%
dfCopy
# Out:
#       Name      Age Gender   Salary
# 0    Alice     25.0      F  50000.0
# 1      Bob     31.0      M      NaN
# 2  Charlie     22.0   None  30000.0
# 3    David  Unknown      M  40000.0
# 4      Eva     27.0      F  60000.0

# %%
dfCopy.fillna({'Age':'Unknown', 'Gender': 'Other'}, inplace=True)

# %%
dfCopy
# Out:
#       Name      Age Gender   Salary
# 0    Alice     25.0      F  50000.0
# 1      Bob     31.0      M      NaN
# 2  Charlie     22.0  Other  30000.0
# 3    David  Unknown      M  40000.0
# 4      Eva     27.0      F  60000.0

# %%
display(dfCopy)
# Out:
#       Name      Age Gender   Salary
# 0    Alice     25.0      F  50000.0
# 1      Bob     31.0      M      NaN
# 2  Charlie     22.0  Other  30000.0
# 3    David  Unknown      M  40000.0
# 4      Eva     27.0      F  60000.0

# %% [markdown]
# ### Fill number features with the *mean* value

# %%
#reset dfCopy
dfCopy = df.copy()
#dfCopy
#dfCopy.info()

# %%
#Using Mode() function to input the values using fillna
dfCopy.fillna({'Salary':dfCopy['Salary'].mean()})
# Out:
#       Name   Age Gender   Salary
# 0    Alice  25.0      F  50000.0
# 1      Bob  31.0      M  45000.0
# 2  Charlie  22.0   None  30000.0
# 3    David   NaN      M  40000.0
# 4      Eva  27.0      F  60000.0

# %%
dfCopy
# Out:
#       Name   Age Gender   Salary
# 0    Alice  25.0      F  50000.0
# 1      Bob  31.0      M      NaN
# 2  Charlie  22.0   None  30000.0
# 3    David   NaN      M  40000.0
# 4      Eva  27.0      F  60000.0

# %% [markdown]
# ### Fill number features with the *mode* value

# %%
#Using Mode() function to inpute the values using fillna
dfCopy.fillna({'Salary':dfCopy['Salary'].mode()[0]}, inplace = True)

# %%
dfCopy
# Out:
#       Name   Age Gender   Salary
# 0    Alice  25.0      F  50000.0
# 1      Bob  31.0      M  30000.0
# 2  Charlie  22.0   None  30000.0
# 3    David   NaN      M  40000.0
# 4      Eva  27.0      F  60000.0

# %%
dfCopy.fillna({'Age':-1, 'Gender':'Other'}, inplace = True)

# %%
dfCopy
# Out:
#       Name   Age Gender   Salary
# 0    Alice  25.0      F  50000.0
# 1      Bob  31.0      M  30000.0
# 2  Charlie  22.0  Other  30000.0
# 3    David  -1.0      M  40000.0
# 4      Eva  27.0      F  60000.0

# %% [markdown]
# # Visualization

# %%
# %matplotlib inline

# %%
dataset
# Out:
#        id  battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0       1           1043     1          1.8         1  14       0           5
# 1       2            841     1          0.5         1   4       1          61
# 2       3           1807     1          2.8         0   1       0          27
# 3       4           1546     0          0.5         1  18       1          25
# 4       5           1434     0          1.4         0  11       1          49
# ..    ...            ...   ...          ...       ...  ..     ...         ...
# 995   996           1700     1          1.9         0   0       1          54
# 996   997            609     0          1.8         1   0       0          13
# 997   998           1185     0          1.4         0   1       1           8
# 998   999           1533     1          0.5         1   0       0          50
# 999  1000           1270     1          0.5         0   4       1          35
#
# ...

# %%
dataset.describe()
# Out:
#             id  battery_power     blue  clock_speed  dual_sim       fc  \
# count  1000.00        1000.00  1000.00      1000.00   1000.00  1000.00
# mean    500.50        1248.51     0.52         1.54      0.52     4.59
# std     288.82         432.46     0.50         0.83      0.50     4.46
# min       1.00         500.00     0.00         0.50      0.00     0.00
# 25%     250.75         895.00     0.00         0.70      0.00     1.00
# 50%     500.50        1246.50     1.00         1.50      1.00     3.00
# 75%     750.25        1629.25     1.00         2.30      1.00     7.00
# max    1000.00        1999.00     1.00         3.00      1.00    19.00
#
#         four_g  int_memory    m_dep  mobile_wt  ...       pc  px_height  \
# count  1000.00     1000.00  1000.00    1000.00  ...  1000.00    1000.00
# mean      0.49       33.65     0.52     139.51  ...    10.05     627.12
# std       0.50       18.13     0.28      34.85  ...     6.10     432.93
# ...

# %%
dataset[dataset["clock_speed"] > 2].groupby("px_width")["int_memory"].sum().plot()
# Out:
# <Axes: xlabel='px_width'>

# %%
dataset["clock_speed"].value_counts().head(10).plot(kind="bar")
# Out:
# <Axes: >

# %% [markdown]
# ## Plot a Dataframe

# %%
dataset_url = ('https://raw.githubusercontent.com/m-mehdi/pandas_tutorials/main/weekly_stocks.csv')

# %%
df = pd.read_csv(dataset_url, parse_dates=['Date'], index_col='Date')

# %%
pd.set_option('display.max.columns', None)

# %%
print(df.head())
# Out:
#               MSFT      FB    AAPL
# Date
# 2021-05-24  249.68  328.73  124.61
# 2021-05-31  250.79  330.35  125.89
# 2021-06-07  257.89  331.26  127.35
# 2021-06-14  259.43  329.66  130.46
# 2021-06-21  265.02  341.37  133.11

# %%
df.plot(y='MSFT', figsize=(5,3))
# Out:
# <Axes: xlabel='Date'>

# %%
df.plot.line(y=['FB', 'AAPL', 'MSFT'], figsize=(5,3))
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# Configure the output

# %%
df.plot(y='FB', figsize=(5,3), title='Original Data', ylabel='EUR')
# Out:
# <Axes: title={'center': 'Original Data'}, xlabel='Date', ylabel='EUR'>

# %% [markdown]
# ## Representing categorical data with rectangular bars
# Resample data by month-end *(rule='M')* and then use the *mean()* method to calculate the average stock price in each month. We also select the last three months of data

# %%
#by month 'M'
#by year 'Y'
#by day 'D'
df_3Months = df.resample(rule='M').mean()[-3:]

# %%
df_3Months
# Out:
#               MSFT      FB    AAPL
# Date
# 2022-03-31  298.40  212.69  166.93
# 2022-04-30  282.09  204.27  163.70
# 2022-05-31  262.80  198.64  147.33

# %%
df_3Months.plot(kind='bar', figsize=(8,3), ylabel='Price')
# Out:
# <Axes: xlabel='Date', ylabel='Price'>

# %% [markdown]
# ## Scatter Plot
# Scatter plots plot data points on the x and y axes to show the correlation between two variables.

# %%
df.plot(kind='scatter', x='MSFT', y='AAPL', figsize=(9,6), color='Green')
# Out:
# <Axes: xlabel='MSFT', ylabel='AAPL'>

# %% [markdown]
# Hexabin Plot
# When the data is very dense!
#
# The gridsize argument specifies the number of hexagons in the x-direction. A larger grid size means more and smaller bins. The default value of the gridsize argument is 100.

# %%
df.plot(kind='hexbin', x='MSFT', y='AAPL', gridsize=20, figsize=(10,6))
# Out:
# <Axes: xlabel='MSFT', ylabel='AAPL'>

# %% [markdown]
# ## Kernel Density Estimat

# %%
df.plot(kind='kde')
# Out:
# <Axes: ylabel='Density'>

# %%
df.plot(kind='kde', bw_method=0.1)
# Out:
# <Axes: ylabel='Density'>

# %%
df.plot(kind='kde', bw_method=1)
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# ## Pie Charts

# %%
df_3Months
# Out:
#               MSFT      FB    AAPL
# Date
# 2022-03-31  298.40  212.69  166.93
# 2022-04-30  282.09  204.27  163.70
# 2022-05-31  262.80  198.64  147.33

# %%
df_3Months.index=['March', 'April', 'May']
df_3Months.plot(kind='pie', y='FB', legend=True)
# Out:
# <Axes: ylabel='FB'>

# %% [markdown]
# # Explore the Gapminder Dataset (Kaggle)
#
# See [Gapminder Dataset](https://www.kaggle.com/code/jhossain/explore-the-gapminder-dataset-with-plotly-express)

# %%
#more advanced
import plotly.express as px
import plotly.express as px # for visualization
import plotly.offline as py
import plotly.graph_objs as go
from plotly.figure_factory import create_table # for creating nice table

# load built-in gapminder dataset from plotly
gapminder = px.data.gapminder()

# %% [markdown]
# ### Data about Europe

# %% [markdown]
# ### Global information using a Pie chart

# %%
#Gapminder Dataset (Kagle: https://www.kaggle.com/code/jhossain/explore-the-gapminder-dataset-with-plotly-express)
df2 = gapminder.query("year == 2007").query("continent == 'Europe'")
df2.loc[df2['pop'] < 2.e6, 'country'] = 'Other countries' # Represent only large countries
fig = px.pie(df2, values='pop', names='country', title='Population of European continent')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Global information using tabular data

# %%
# create a publication quality table
table = create_table(gapminder.head(10))
py.iplot(table)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Data about Portugal (<=2007)

# %%
# filtering data for Canada and store into a variable called canada_data
portugalData = gapminder.query("country == 'Portugal' ")

# %%
#or portugalData
table = create_table(portugalData.tail(10))
py.iplot(table)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# create bar charts
fig = px.bar(portugalData, x='year', y='pop', height=400)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# let's add color by lifeExp and other parameters
fig = px.bar(portugalData, x='year', y='pop', color='gdpPercap', labels={'pop': 'Population of Portugal'}, height=400)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### World Distribution in 2007

# %%
# filter 2007 data only from dataset
gapminder2007 = gapminder.query('year ==2007')
#gapminder2007 = gapminder.query('year > 2005 and year<=2007')

# create scatter plot
fig = px.scatter(gapminder2007, x='gdpPercap', y='lifeExp')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
gapminder2007
# Out:
#                  country continent  year  lifeExp       pop  gdpPercap  \
# 11           Afghanistan      Asia  2007    43.83  31889923     974.58
# 23               Albania    Europe  2007    76.42   3600523    5937.03
# 35               Algeria    Africa  2007    72.30  33333216    6223.37
# 47                Angola    Africa  2007    42.73  12420476    4797.23
# 59             Argentina  Americas  2007    75.32  40301927   12779.38
# ...                  ...       ...   ...      ...       ...        ...
# 1655             Vietnam      Asia  2007    74.25  85262356    2441.58
# 1667  West Bank and Gaza      Asia  2007    73.42   4018332    3025.35
# 1679         Yemen, Rep.      Asia  2007    62.70  22211743    2280.77
# 1691              Zambia    Africa  2007    42.38  11746035    1271.21
# 1703            Zimbabwe    Africa  2007    43.49  12311143     469.71
#
#      iso_alpha  iso_num
# 11         AFG        4
# 23         ALB        8
# 35         DZA       12
# ...
